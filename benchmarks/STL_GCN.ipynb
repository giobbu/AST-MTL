# %% [markdown]
# ## General Import

# %%
# !pip install geojson geopandas osmnx spektral matplotlib==3.1.3
# from google.colab import files
# from google.colab import drive

# drive.mount('/content/drive')

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf

from sklearn.preprocessing import MinMaxScaler

import gc
import time
import seaborn as sns; sns.set()

import os 
# Disable warnings, set Matplotlib inline plotting and load Pandas package
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
#pd.options.display.mpl_style = 'default'
from datetime import datetime
import numpy as np
from datetime import datetime, timedelta
from pytz import timezone
from dateutil import tz
import geojson
import geopandas as gpd
from fiona.crs import from_epsg
import os, json
from shapely.geometry import shape, Point, Polygon, MultiPoint
# %matplotlib inline
import matplotlib.pyplot as plt
from geopandas.tools import sjoin

import matplotlib.cm as cm

import folium
import shapely.geometry

from branca.colormap import  linear
import json
import branca.colormap as cm
import matplotlib.colors as colors
# %matplotlib inline

import networkx as nx
import pickle

import osmnx as ox
ox.config(log_console=True, use_cache=True)
ox.__version__

import matplotlib.colors as mcolors

# %%
import tensorflow as tf
from tensorflow.keras import Model
from spektral.layers import GCNConv,  DiffusionConv, GATConv, GCSConv, GeneralConv, GatedGraphConv
from spektral.utils import gcn_filter
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import SparseCategoricalAccuracy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers

# %%
path_graph = 'drive/MyDrive/Colab Notebooks/MTL traffic forecasting/direct graph/GRAPH_ADJ.pkl'

path_feat_flow = 'drive/MyDrive/Colab Notebooks/MTL traffic forecasting/direct graph/FEATURES_FLOW.csv'
path_feat_vel = 'drive/MyDrive/Colab Notebooks/MTL traffic forecasting/direct graph/FEATURES_VEL.csv'

with open(path_graph,'rb') as f:
    graph, adj_matrix, edges, G = pickle.load(f)

adj_mx = nx.to_numpy_matrix(graph)

# flow
features_flow = pd.read_csv(path_feat_flow).iloc[:,1:].values
# vel
features_vel = pd.read_csv(path_feat_vel).iloc[:,1:].values

# %%
adj_matrix.shape
# Out:
# (5975, 5975)

# %%
features_flow.shape
# Out:
# (2832, 5976)

# %%
features_vel.shape
# Out:
# (2832, 5976)

# %%
# PARAMETERS

# %%
inputs = 12

batch_train = 32 # best 32
batch_test = 1

# %% [markdown]
# ## split train/val/test

# %%
data_flow = features_flow[:, :-1]
data_vel = features_vel[:, :-1]

data = np.concatenate([data_flow, data_vel], axis=1)

# %%
data.shape
# Out:
# (2832, 11950)

# %%
# Train/test split
data_tr, data_te = data[:-168*2*2, :], data[-168*2*2:, :]

# %%
# Covariates

# %%
datetime = features_flow[:, -1]

# for figures
print_datetime = datetime[-168*2*2+inputs:]

DATETIME = pd.DataFrame(datetime, columns=['Datetime'])
DATETIME['Datetime'] = pd.to_datetime(DATETIME['Datetime'])

DATETIME['minutes'] = DATETIME['Datetime'].dt.minute
DATETIME['hour'] = DATETIME['Datetime'].dt.hour

DATETIME['hour_x']=np.sin(DATETIME.hour*(2.*np.pi/23))
DATETIME['hour_y']=np.cos(DATETIME.hour*(2.*np.pi/23))

DATETIME['day'] = DATETIME['Datetime'].dt.day
DATETIME['DayOfWeek'] = DATETIME['Datetime'].dt.dayofweek

DATETIME['WorkingDays'] = DATETIME['DayOfWeek'].apply(lambda y: 2 if y < 5 else y)
DATETIME['WorkingDays'] = DATETIME['WorkingDays'].apply(lambda y: 1 if y == 5 else y)
DATETIME['WorkingDays'] = DATETIME['WorkingDays'].apply(lambda y: 0 if y == 6 else y)

DATETIME = DATETIME.drop(['Datetime','minutes','hour','day'], axis=1).values

# temporal features = 4
feat_time = 4

# datetime Train/test split
time_tr, time_te = DATETIME[:-168*2*2, :], DATETIME[-168*2*2:, :]

# %% [markdown]
# ## scale data

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaler_cov = MinMaxScaler(feature_range=(0, 1))

# fit and transform
scaled_tr = scaler.fit_transform(data_tr)
# transform
scaled_te = scaler.transform(data_te)

# fit and transform
scaled_tr_cov = scaler_cov.fit_transform(time_tr)
# transform
scaled_te_cov = scaler_cov.transform(time_te)

# %% [markdown]
# ## prepare data for deep learning

# %%
def prepare_data_DL(INPUT, FEAT, BATCH):
    
    dataset = FEAT.reshape(FEAT.shape[0], FEAT.shape[1]) 
    dataset = tf.data.Dataset.from_tensor_slices(dataset)

    inputs = dataset.window(INPUT,  shift=1,  stride=1,  drop_remainder=True)
    inputs = inputs.flat_map(lambda window: window.batch(INPUT))

    targets = dataset.window(INPUT, shift=1,  stride=1,  drop_remainder=True).skip(INPUT)
    targets = targets.flat_map(lambda window: window.batch(INPUT))

    dataset = tf.data.Dataset.zip((inputs, targets))
    dataset = dataset.batch(BATCH).prefetch(tf.data.experimental.AUTOTUNE)


    return dataset

# %%
# features
loader_tr = prepare_data_DL(inputs, scaled_tr, batch_train)
loader_te = prepare_data_DL(inputs, scaled_te, batch_test)

# covariates
loader_tr_cov = prepare_data_DL(inputs, scaled_tr_cov, batch_train)
loader_te_cov = prepare_data_DL(inputs, scaled_te_cov, batch_test)

# %%
l2_reg = 5e-4  # Regularization rate for l2

# Build model
class GCN_Net(Model):
    
    def __init__(self, **kwargs):
        
        super().__init__(**kwargs)



###################
        self.gcn_flow_0 = GCNConv(12, activation="relu", kernel_regularizer=l2(l2_reg), use_bias=False)
        self.gcn_flow_1 = GCNConv(12, activation="relu", kernel_regularizer=l2(l2_reg), use_bias=False)
        
        self.dense_flow = tf.keras.layers.Dense(150, kernel_regularizer=regularizers.l2(0.001))
        self.drop_flow = tf.keras.layers.Dropout(0.1)
        self.dense_flow_fin = tf.keras.layers.Dense(5975*12, kernel_regularizer=regularizers.l2(0.001))
        

##########################


        self.gcn_vel_0 = GCNConv(12, activation="relu", kernel_regularizer=l2(l2_reg), use_bias=False)
        self.gcn_vel_1 = GCNConv(12, activation="relu", kernel_regularizer=l2(l2_reg), use_bias=False)

        self.dense_vel = tf.keras.layers.Dense(150, kernel_regularizer=regularizers.l2(0.001))
        self.drop_vel = tf.keras.layers.Dropout(0.1)
        self.dense_vel_fin = tf.keras.layers.Dense(5975*12, kernel_regularizer=regularizers.l2(0.001))
        


##################################
        self.repeat = tf.keras.layers.RepeatVector(12)
        self.add = tf.keras.layers.Add()
        self.reshape = tf.keras.layers.Reshape([12, 5975])
        self.drop = tf.keras.layers.Dropout(0.1)
        self.flat = tf.keras.layers.Flatten()
        

    def call(self, flow_vel, a, cov):
      
        sparse_a = tf.sparse.from_dense(a)

        # flow
        flow = flow_vel[:, :, :-5975]
        # velocity
        vel = flow_vel[:, :, -5975:]

        # shape for gcn
        flow = tf.reshape(flow, [flow.shape[0], flow.shape[2], flow.shape[1]])
        vel = tf.reshape(vel, [vel.shape[0], vel.shape[2], vel.shape[1]])

        # two gcn on flow and vel
        gcn_flow = self.gcn_flow_0([flow, sparse_a])
        gcn_flow = self.gcn_flow_1([gcn_flow, sparse_a])

        gcn_vel = self.gcn_vel_0([vel, sparse_a])
        gcn_vel = self.gcn_vel_1([gcn_vel, sparse_a])


        # shape for lstm
        flow = tf.reshape(gcn_flow, [gcn_flow.shape[0], gcn_flow.shape[2], gcn_flow.shape[1]])[:,-1,:]
        vel = tf.reshape(gcn_vel, [gcn_vel.shape[0], gcn_vel.shape[2], gcn_vel.shape[1]])[:,-1,:]
        print(vel.shape)

        # flow = self.repeat(flow)
        # vel = self.repeat(vel)

        # # output flow_vel - covariates
        # cov = tf.cast(cov, dtype=tf.float32)
        # flow_cov = tf.concat([flow, cov], axis=2)
        # vel_cov = tf.concat([vel, cov], axis=2)

        # flow
        flow = self.dense_flow(flow)
        flow = self.drop(flow)
        flow = self.dense_flow_fin(flow)
        flow = self.reshape(flow)

        # velocity
        vel = self.dense_vel(vel)
        vel = self.drop(vel)
        vel = self.dense_vel_fin(vel)
        vel = self.reshape(vel)

        final = tf.concat([flow, vel], axis=-1)

        return final


# Create model
model = GCN_Net()
optimizer = Adam(lr=0.001)
loss_fn = tf.keras.losses.MeanAbsoluteError()

# %%
adj_matrix = gcn_filter(adj_matrix, symmetric=True)

# %%
# Training function
@tf.function
def train_on_batch(inputs, target, cov):
    
    loss = 0

    with tf.GradientTape() as tape:
        
        predictions = model(inputs, adj_matrix, cov,  training=True)
        
        loss = loss_fn(target, predictions)

    variables = model.trainable_variables 

    gradients = tape.gradient(loss, variables)

    optimizer.apply_gradients(zip(gradients, variables))
    
    return loss

# %%
EPOCHS = 250

# Keep results for plotting
train_loss_results = []

samples_cov = list(loader_tr_cov)

for epoch in range(EPOCHS):
    
    start = time.time()

    epoch_loss_avg = tf.keras.metrics.Mean()
     
    step = 0

    for batch in loader_tr:

        cov = samples_cov[step]
        past_cov = cov[0]
        fut_cov = cov[1]
        
        # Training step
        inputs, target = batch
        
        loss = train_on_batch(inputs, target, past_cov)
        
        # Track progress
        epoch_loss_avg.update_state(loss)

        step+=1

    # End epoch
    train_loss_results.append(epoch_loss_avg.result())

    if epoch % 10 == 0:
            print("Epoch {}: Loss MAE: {:.3f}".format(epoch, epoch_loss_avg.result()))
        
print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# (32, 5975)
# (32, 5975)
# (25, 5975)
# Epoch 0: Loss MAE: 0.154
# Epoch 10: Loss MAE: 0.083
# Epoch 20: Loss MAE: 0.081
# Epoch 30: Loss MAE: 0.079
# Epoch 40: Loss MAE: 0.082
# Epoch 50: Loss MAE: 0.073
# Epoch 60: Loss MAE: 0.073
# Epoch 70: Loss MAE: 0.074
# Epoch 80: Loss MAE: 0.072
# Epoch 90: Loss MAE: 0.071
# Epoch 100: Loss MAE: 0.071
# Epoch 110: Loss MAE: 0.071
# Epoch 120: Loss MAE: 0.070
# Epoch 130: Loss MAE: 0.070
# Epoch 140: Loss MAE: 0.071
# Epoch 150: Loss MAE: 0.070
# Epoch 160: Loss MAE: 0.068
# Epoch 170: Loss MAE: 0.067
# Epoch 180: Loss MAE: 0.068
# Epoch 190: Loss MAE: 0.068
# Epoch 200: Loss MAE: 0.067
# Epoch 210: Loss MAE: 0.067
# Epoch 220: Loss MAE: 0.067
# Epoch 230: Loss MAE: 0.066
# Epoch 240: Loss MAE: 0.066
# Time taken for 1 epoch 4.201840162277222 sec

# %%
fig, axes = plt.subplots(1, sharex=True, figsize=(12, 8))
fig.suptitle('Training Metrics')

axes.set_ylabel("Loss (MAE)", fontsize=14)
axes.plot(train_loss_results)
axes.set_xlabel("Epoch", fontsize=14)
plt.show()

# %%
def inverse_transform(forecasts, scaler):
    # invert scaling
    inv_pred = scaler.inverse_transform(forecasts)
    return inv_pred

# %%
def evaluate_forecasts(targets, forecasts, n_seq):
    
    list_rmse = []
    list_mae = []
    
    for i in range(n_seq):
        true = np.vstack([target[i] for target in targets])
        predicted = np.vstack([forecast[i] for forecast in forecasts])
        
        rmse = np.sqrt((np.square(true - predicted)).mean(axis=0))
        mae = np.absolute(true - predicted).mean(axis=0)
        
        list_rmse.append(rmse)
        list_mae.append(mae)
        
    list_rmse = np.vstack(list_rmse)
    list_mae = np.vstack(list_mae)
    
    return list_rmse, list_mae

# %%
forecasts = []
targets = []

rmse_list = []
mae_list = []

samples_cov = list(loader_te_cov)

    
for (step, (inp, targ)) in enumerate(loader_te):
    
            
        timestamp = print_datetime[step]
        print(timestamp)

        cov = samples_cov[step]
        past_cov = cov[0]
        fut_cov = cov[1]
        
        pred  = model(inp, adj_matrix, past_cov, training=False)
        print(pred.shape)
        
        truth = inverse_transform(targ[0],  scaler)
        pred = inverse_transform(pred[0],  scaler)
        
        forecasts.append(pred)
        targets.append(truth)

        rmse, mae = evaluate_forecasts(targets, forecasts, 12)
           
        rmse_list.append(rmse)
        mae_list.append(mae)

         
        # fig = plt.figure(figsize=(10, 5))   
        # plt.plot(np.sum(pred[:, :5975], axis=1), label='Prediction') 
        # plt.plot(np.sum(truth[:, :5975], axis=1), label='Truth') 
        # plt.title('Sum flow Prediction on all highways in Belgium')
        # plt.legend()
        # plt.show()
        # fig.clear()
        # plt.close(fig)       
        # plt.show()

        # fig = plt.figure(figsize=(10, 5))   
        # plt.plot(np.mean(pred[:, 5975:], axis=1), label='Prediction') 
        # plt.plot(np.mean(truth[:, 5975:], axis=1), label='Truth') 
        # plt.title('Sum Velocity Prediction on all highways in Belgium')
        # plt.legend()
        # plt.show()
        # fig.clear()
        # plt.close(fig)       
        # plt.show()

        print('* Time step '+str(step))
        print('* Prediction Accuracy (MAE) '+ str(np.absolute(truth - pred).mean()))
        print('----')
        
        
        new_instance = scaled_te[step,:].reshape(1,-1)
        new_instance_cov = scaled_te_cov[step,:].reshape(1,-1)
    
        scaled_tr = np.vstack([scaled_tr[1:], new_instance])
        scaled_tr_cov = np.vstack([scaled_tr_cov[1:], new_instance_cov])
        
        loader_new = prepare_data_DL(12, scaled_tr, batch_train)
        loader_new_cov = prepare_data_DL(12, scaled_tr_cov, batch_train)
        
        UPDATE = 2
        time_update = 168*2

        if step % time_update == 0:

          print('')
          print('* Time to UPDATE the Model after '+str(time_update)+' steps')
          print('')
          sample_cov_new = list(loader_new_cov) 
          

          for epoch in range(UPDATE):

            step_new = 0
            
            for batch in loader_new:

              cov_new = sample_cov_new[step_new]

              past_cov_new = cov_new[0]
              future_cov_new = cov_new[1]
              
              inp_new, targ_new = batch

              loss = train_on_batch(inp_new, targ_new, past_cov_new)

              # Track progress
              epoch_loss_avg.update_state(loss)

              # End epoch
              train_loss_results.append(epoch_loss_avg.result())

              step_new+=1
# Out:
# 2019-02-15 06:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 0
# * Prediction Accuracy (MAE) 8.96503017349403
# ----
#
# * Time to UPDATE the Model after 336 steps
#
# 2019-02-15 06:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 1
# * Prediction Accuracy (MAE) 7.507878627902393
# ----
# 2019-02-15 07:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 2
# * Prediction Accuracy (MAE) 7.787554489082879
# ----
# 2019-02-15 07:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 3
# * Prediction Accuracy (MAE) 10.626422828921593
# ----
# 2019-02-15 08:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 4
# * Prediction Accuracy (MAE) 8.32346475141048
# ----
# 2019-02-15 08:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 5
# * Prediction Accuracy (MAE) 9.330802150617766
# ----
# 2019-02-15 09:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 6
# * Prediction Accuracy (MAE) 9.226262504317747
# ----
# 2019-02-15 09:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 7
# * Prediction Accuracy (MAE) 18.469520395615042
# ----
# 2019-02-15 10:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 8
# * Prediction Accuracy (MAE) 8.056743181504219
# ----
# 2019-02-15 10:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 9
# * Prediction Accuracy (MAE) 7.210440013637601
# ----
# 2019-02-15 11:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 10
# * Prediction Accuracy (MAE) 12.404373969577023
# ----
# 2019-02-15 11:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 11
# * Prediction Accuracy (MAE) 9.038704055448944
# ----
# 2019-02-15 12:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 12
# * Prediction Accuracy (MAE) 6.886462064812781
# ----
# 2019-02-15 12:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 13
# * Prediction Accuracy (MAE) 6.809991065666106
# ----
# 2019-02-15 13:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 14
# * Prediction Accuracy (MAE) 6.651375608579381
# ----
# 2019-02-15 13:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 15
# * Prediction Accuracy (MAE) 6.542586343166285
# ----
# 2019-02-15 14:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 16
# * Prediction Accuracy (MAE) 6.485547991357118
# ----
# 2019-02-15 14:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 17
# * Prediction Accuracy (MAE) 7.21946517040185
# ----
# 2019-02-15 15:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 18
# * Prediction Accuracy (MAE) 7.338083839934584
# ----
# 2019-02-15 15:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 19
# * Prediction Accuracy (MAE) 6.717586932217993
# ----
# 2019-02-15 16:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 20
# * Prediction Accuracy (MAE) 9.80145726032421
# ----
# 2019-02-15 16:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 21
# * Prediction Accuracy (MAE) 7.219055976252035
# ----
# 2019-02-15 17:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 22
# * Prediction Accuracy (MAE) 8.149264447124382
# ----
# 2019-02-15 17:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 23
# * Prediction Accuracy (MAE) 6.778798175198118
# ----
# 2019-02-15 18:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 24
# * Prediction Accuracy (MAE) 6.75962749376134
# ----
# 2019-02-15 18:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 25
# * Prediction Accuracy (MAE) 8.233085645369982
# ----
# 2019-02-15 19:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 26
# * Prediction Accuracy (MAE) 7.6519562129875744
# ----
# 2019-02-15 19:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 27
# * Prediction Accuracy (MAE) 7.17721524481644
# ----
# 2019-02-15 20:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 28
# * Prediction Accuracy (MAE) 7.146562420138156
# ----
# 2019-02-15 20:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 29
# * Prediction Accuracy (MAE) 7.289922522598743
# ----
# 2019-02-15 21:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 30
# * Prediction Accuracy (MAE) 8.183569208446489
# ----
# 2019-02-15 21:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 31
# * Prediction Accuracy (MAE) 7.646022639629406
# ----
# 2019-02-15 22:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 32
# * Prediction Accuracy (MAE) 8.282119366718705
# ----
# 2019-02-15 22:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 33
# * Prediction Accuracy (MAE) 8.907240759476634
# ----
# 2019-02-15 23:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 34
# * Prediction Accuracy (MAE) 7.505056631346173
# ----
# 2019-02-15 23:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 35
# * Prediction Accuracy (MAE) 7.285487668845748
# ----
# 2019-02-16 00:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 36
# * Prediction Accuracy (MAE) 10.557673569603482
# ----
# 2019-02-16 00:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 37
# * Prediction Accuracy (MAE) 7.346164205411968
# ----
# 2019-02-16 01:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 38
# * Prediction Accuracy (MAE) 7.6284390914530595
# ----
# 2019-02-16 01:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 39
# * Prediction Accuracy (MAE) 7.863346299420574
# ----
# 2019-02-16 02:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 40
# * Prediction Accuracy (MAE) 7.3324085927595
# ----
# 2019-02-16 02:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 41
# * Prediction Accuracy (MAE) 7.405887614322003
# ----
# 2019-02-16 03:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 42
# * Prediction Accuracy (MAE) 8.833555537609394
# ----
# 2019-02-16 03:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 43
# * Prediction Accuracy (MAE) 7.542826020181469
# ----
# 2019-02-16 04:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 44
# * Prediction Accuracy (MAE) 6.363959489078545
# ----
# 2019-02-16 04:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 45
# * Prediction Accuracy (MAE) 7.581662921726428
# ----
# 2019-02-16 05:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 46
# * Prediction Accuracy (MAE) 7.875359244553601
# ----
# 2019-02-16 05:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 47
# * Prediction Accuracy (MAE) 6.481945336897257
# ----
# 2019-02-16 06:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 48
# * Prediction Accuracy (MAE) 6.674766152531851
# ----
# 2019-02-16 06:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 49
# * Prediction Accuracy (MAE) 6.365003370064673
# ----
# 2019-02-16 07:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 50
# * Prediction Accuracy (MAE) 7.626593097515037
# ----
# 2019-02-16 07:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 51
# * Prediction Accuracy (MAE) 6.98342055330934
# ----
# 2019-02-16 08:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 52
# * Prediction Accuracy (MAE) 6.524938079020786
# ----
# 2019-02-16 08:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 53
# * Prediction Accuracy (MAE) 6.62689996976268
# ----
# 2019-02-16 09:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 54
# * Prediction Accuracy (MAE) 7.0959491827238885
# ----
# 2019-02-16 09:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 55
# * Prediction Accuracy (MAE) 7.382817755575388
# ----
# 2019-02-16 10:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 56
# * Prediction Accuracy (MAE) 8.291011760410703
# ----
# 2019-02-16 10:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 57
# * Prediction Accuracy (MAE) 7.078752574603661
# ----
# 2019-02-16 11:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 58
# * Prediction Accuracy (MAE) 7.27123882839146
# ----
# 2019-02-16 11:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 59
# * Prediction Accuracy (MAE) 7.631920286444611
# ----
# 2019-02-16 12:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 60
# * Prediction Accuracy (MAE) 8.030567851759498
# ----
# 2019-02-16 12:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 61
# * Prediction Accuracy (MAE) 7.56972380285043
# ----
# 2019-02-16 13:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 62
# * Prediction Accuracy (MAE) 7.975805330229449
# ----
# 2019-02-16 13:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 63
# * Prediction Accuracy (MAE) 8.406929079602795
# ----
# 2019-02-16 14:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 64
# * Prediction Accuracy (MAE) 8.188998721289815
# ----
# 2019-02-16 14:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 65
# * Prediction Accuracy (MAE) 9.797281367522519
# ----
# 2019-02-16 15:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 66
# * Prediction Accuracy (MAE) 7.98953978233614
# ----
# 2019-02-16 15:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 67
# * Prediction Accuracy (MAE) 10.36612900671272
# ----
# 2019-02-16 16:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 68
# * Prediction Accuracy (MAE) 8.012189991219504
# ----
# 2019-02-16 16:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 69
# * Prediction Accuracy (MAE) 8.762139531373325
# ----
# 2019-02-16 17:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 70
# * Prediction Accuracy (MAE) 7.906848674452127
# ----
# 2019-02-16 17:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 71
# * Prediction Accuracy (MAE) 8.263401905802125
# ----
# 2019-02-16 18:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 72
# * Prediction Accuracy (MAE) 8.518969145955369
# ----
# 2019-02-16 18:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 73
# * Prediction Accuracy (MAE) 10.479297908314974
# ----
# 2019-02-16 19:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 74
# * Prediction Accuracy (MAE) 10.64771288111666
# ----
# 2019-02-16 19:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 75
# * Prediction Accuracy (MAE) 9.965343751973466
# ----
# 2019-02-16 20:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 76
# * Prediction Accuracy (MAE) 11.104796053950007
# ----
# 2019-02-16 20:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 77
# * Prediction Accuracy (MAE) 9.067925768912122
# ----
# 2019-02-16 21:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 78
# * Prediction Accuracy (MAE) 10.969171265525562
# ----
# 2019-02-16 21:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 79
# * Prediction Accuracy (MAE) 10.699478301029037
# ----
# 2019-02-16 22:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 80
# * Prediction Accuracy (MAE) 14.373544204108734
# ----
# 2019-02-16 22:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 81
# * Prediction Accuracy (MAE) 10.67385288318071
# ----
# 2019-02-16 23:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 82
# * Prediction Accuracy (MAE) 10.388735066259027
# ----
# 2019-02-16 23:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 83
# * Prediction Accuracy (MAE) 9.32286974013322
# ----
# 2019-02-17 00:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 84
# * Prediction Accuracy (MAE) 9.900341098694149
# ----
# 2019-02-17 00:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 85
# * Prediction Accuracy (MAE) 9.949228777985727
# ----
# 2019-02-17 01:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 86
# * Prediction Accuracy (MAE) 11.782355600445692
# ----
# 2019-02-17 01:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 87
# * Prediction Accuracy (MAE) 9.56267028287426
# ----
# 2019-02-17 02:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 88
# * Prediction Accuracy (MAE) 10.31389362270403
# ----
# 2019-02-17 02:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 89
# * Prediction Accuracy (MAE) 10.74676524328317
# ----
# 2019-02-17 03:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 90
# * Prediction Accuracy (MAE) 8.388691246533826
# ----
# 2019-02-17 03:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 91
# * Prediction Accuracy (MAE) 8.781284427027149
# ----
# 2019-02-17 04:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 92
# * Prediction Accuracy (MAE) 9.153442669633439
# ----
# 2019-02-17 04:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 93
# * Prediction Accuracy (MAE) 10.502689979337395
# ----
# 2019-02-17 05:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 94
# * Prediction Accuracy (MAE) 9.570987150422477
# ----
# 2019-02-17 05:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 95
# * Prediction Accuracy (MAE) 11.077321216332606
# ----
# 2019-02-17 06:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 96
# * Prediction Accuracy (MAE) 10.493720463572348
# ----
# 2019-02-17 06:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 97
# * Prediction Accuracy (MAE) 8.883451334900899
# ----
# 2019-02-17 07:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 98
# * Prediction Accuracy (MAE) 8.811594279641076
# ----
# 2019-02-17 07:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 99
# * Prediction Accuracy (MAE) 8.438935057214625
# ----
# 2019-02-17 08:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 100
# * Prediction Accuracy (MAE) 8.178086054012773
# ----
# 2019-02-17 08:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 101
# * Prediction Accuracy (MAE) 8.783358649158119
# ----
# 2019-02-17 09:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 102
# * Prediction Accuracy (MAE) 8.950302659774295
# ----
# 2019-02-17 09:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 103
# * Prediction Accuracy (MAE) 9.405473339112497
# ----
# 2019-02-17 10:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 104
# * Prediction Accuracy (MAE) 9.424404243073722
# ----
# 2019-02-17 10:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 105
# * Prediction Accuracy (MAE) 8.885153866448379
# ----
# 2019-02-17 11:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 106
# * Prediction Accuracy (MAE) 9.627422356892422
# ----
# 2019-02-17 11:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 107
# * Prediction Accuracy (MAE) 8.754908609703538
# ----
# 2019-02-17 12:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 108
# * Prediction Accuracy (MAE) 9.531651871954205
# ----
# 2019-02-17 12:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 109
# * Prediction Accuracy (MAE) 8.593411648646528
# ----
# 2019-02-17 13:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 110
# * Prediction Accuracy (MAE) 8.148380061262715
# ----
# 2019-02-17 13:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 111
# * Prediction Accuracy (MAE) 8.924253346048424
# ----
# 2019-02-17 14:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 112
# * Prediction Accuracy (MAE) 9.627400045805063
# ----
# 2019-02-17 14:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 113
# * Prediction Accuracy (MAE) 9.308217828957268
# ----
# 2019-02-17 15:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 114
# * Prediction Accuracy (MAE) 9.420335391863116
# ----
# 2019-02-17 15:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 115
# * Prediction Accuracy (MAE) 8.255797021469833
# ----
# 2019-02-17 16:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 116
# * Prediction Accuracy (MAE) 8.032462350453695
# ----
# 2019-02-17 16:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 117
# * Prediction Accuracy (MAE) 7.80520745502217
# ----
# 2019-02-17 17:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 118
# * Prediction Accuracy (MAE) 9.605575168605661
# ----
# 2019-02-17 17:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 119
# * Prediction Accuracy (MAE) 8.87310441000904
# ----
# 2019-02-17 18:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 120
# * Prediction Accuracy (MAE) 9.961496188476792
# ----
# 2019-02-17 18:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 121
# * Prediction Accuracy (MAE) 8.413770620849583
# ----
# 2019-02-17 19:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 122
# * Prediction Accuracy (MAE) 8.452925751262764
# ----
# 2019-02-17 19:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 123
# * Prediction Accuracy (MAE) 8.460846388420403
# ----
# 2019-02-17 20:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 124
# * Prediction Accuracy (MAE) 9.640713686471448
# ----
# 2019-02-17 20:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 125
# * Prediction Accuracy (MAE) 8.655375760134683
# ----
# 2019-02-17 21:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 126
# * Prediction Accuracy (MAE) 8.145276371868235
# ----
# 2019-02-17 21:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 127
# * Prediction Accuracy (MAE) 8.168559654555487
# ----
# 2019-02-17 22:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 128
# * Prediction Accuracy (MAE) 6.998353804629391
# ----
# 2019-02-17 22:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 129
# * Prediction Accuracy (MAE) 7.815297858857257
# ----
# 2019-02-17 23:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 130
# * Prediction Accuracy (MAE) 7.936866304411672
# ----
# 2019-02-17 23:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 131
# * Prediction Accuracy (MAE) 9.091565988099282
# ----
# 2019-02-18 00:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 132
# * Prediction Accuracy (MAE) 8.430083636323403
# ----
# 2019-02-18 00:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 133
# * Prediction Accuracy (MAE) 9.902616228721598
# ----
# 2019-02-18 01:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 134
# * Prediction Accuracy (MAE) 7.706751566196539
# ----
# 2019-02-18 01:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 135
# * Prediction Accuracy (MAE) 8.1449677084818
# ----
# 2019-02-18 02:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 136
# * Prediction Accuracy (MAE) 8.22314212163504
# ----
# 2019-02-18 02:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 137
# * Prediction Accuracy (MAE) 8.383071155185249
# ----
# 2019-02-18 03:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 138
# * Prediction Accuracy (MAE) 9.340365794389468
# ----
# 2019-02-18 03:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 139
# * Prediction Accuracy (MAE) 7.707592554355758
# ----
# 2019-02-18 04:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 140
# * Prediction Accuracy (MAE) 6.818495866636828
# ----
# 2019-02-18 04:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 141
# * Prediction Accuracy (MAE) 6.18782823699959
# ----
# 2019-02-18 05:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 142
# * Prediction Accuracy (MAE) 6.4236460196119145
# ----
# 2019-02-18 05:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 143
# * Prediction Accuracy (MAE) 6.928679155396086
# ----
# 2019-02-18 06:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 144
# * Prediction Accuracy (MAE) 6.61942625843433
# ----
# 2019-02-18 06:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 145
# * Prediction Accuracy (MAE) 7.774068565168106
# ----
# 2019-02-18 07:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 146
# * Prediction Accuracy (MAE) 5.707469250898864
# ----
# 2019-02-18 07:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 147
# * Prediction Accuracy (MAE) 5.713236231940748
# ----
# 2019-02-18 08:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 148
# * Prediction Accuracy (MAE) 6.093461629868418
# ----
# 2019-02-18 08:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 149
# * Prediction Accuracy (MAE) 6.324801855689611
# ----
# 2019-02-18 09:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 150
# * Prediction Accuracy (MAE) 7.654434497601783
# ----
# 2019-02-18 09:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 151
# * Prediction Accuracy (MAE) 7.565437392491577
# ----
# 2019-02-18 10:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 152
# * Prediction Accuracy (MAE) 6.172141690199343
# ----
# 2019-02-18 10:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 153
# * Prediction Accuracy (MAE) 9.330274344100182
# ----
# 2019-02-18 11:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 154
# * Prediction Accuracy (MAE) 6.58557681594793
# ----
# 2019-02-18 11:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 155
# * Prediction Accuracy (MAE) 8.366803535489513
# ----
# 2019-02-18 12:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 156
# * Prediction Accuracy (MAE) 9.90079985867022
# ----
# 2019-02-18 12:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 157
# * Prediction Accuracy (MAE) 6.5052821986516305
# ----
# 2019-02-18 13:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 158
# * Prediction Accuracy (MAE) 6.328072087330296
# ----
# 2019-02-18 13:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 159
# * Prediction Accuracy (MAE) 6.722504730582009
# ----
# 2019-02-18 14:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 160
# * Prediction Accuracy (MAE) 6.742372261098702
# ----
# 2019-02-18 14:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 161
# * Prediction Accuracy (MAE) 7.109046284485584
# ----
# 2019-02-18 15:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 162
# * Prediction Accuracy (MAE) 7.15435892734515
# ----
# 2019-02-18 15:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 163
# * Prediction Accuracy (MAE) 7.275543739622102
# ----
# 2019-02-18 16:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 164
# * Prediction Accuracy (MAE) 7.296658099512508
# ----
# 2019-02-18 16:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 165
# * Prediction Accuracy (MAE) 7.452715722301024
# ----
# 2019-02-18 17:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 166
# * Prediction Accuracy (MAE) 9.206586678144113
# ----
# 2019-02-18 17:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 167
# * Prediction Accuracy (MAE) 9.000983129477634
# ----
# 2019-02-18 18:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 168
# * Prediction Accuracy (MAE) 10.20442087593185
# ----
# 2019-02-18 18:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 169
# * Prediction Accuracy (MAE) 6.995027854157059
# ----
# 2019-02-18 19:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 170
# * Prediction Accuracy (MAE) 9.509533296120171
# ----
# 2019-02-18 19:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 171
# * Prediction Accuracy (MAE) 7.436750514203826
# ----
# 2019-02-18 20:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 172
# * Prediction Accuracy (MAE) 6.761949152870991
# ----
# 2019-02-18 20:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 173
# * Prediction Accuracy (MAE) 7.100055758603148
# ----
# 2019-02-18 21:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 174
# * Prediction Accuracy (MAE) 8.721482373976842
# ----
# 2019-02-18 21:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 175
# * Prediction Accuracy (MAE) 8.037796262212641
# ----
# 2019-02-18 22:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 176
# * Prediction Accuracy (MAE) 10.929083392139818
# ----
# 2019-02-18 22:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 177
# * Prediction Accuracy (MAE) 6.734603813988497
# ----
# 2019-02-18 23:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 178
# * Prediction Accuracy (MAE) 7.339650858574991
# ----
# 2019-02-18 23:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 179
# * Prediction Accuracy (MAE) 7.379625356551286
# ----
# 2019-02-19 00:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 180
# * Prediction Accuracy (MAE) 6.475210242481161
# ----
# 2019-02-19 00:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 181
# * Prediction Accuracy (MAE) 7.979754837707446
# ----
# 2019-02-19 01:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 182
# * Prediction Accuracy (MAE) 8.332746442799913
# ----
# 2019-02-19 01:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 183
# * Prediction Accuracy (MAE) 9.503867061772059
# ----
# 2019-02-19 02:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 184
# * Prediction Accuracy (MAE) 6.942208559301853
# ----
# 2019-02-19 02:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 185
# * Prediction Accuracy (MAE) 6.817021061499155
# ----
# 2019-02-19 03:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 186
# * Prediction Accuracy (MAE) 7.100336868101093
# ----
# 2019-02-19 03:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 187
# * Prediction Accuracy (MAE) 6.934029049316981
# ----
# 2019-02-19 04:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 188
# * Prediction Accuracy (MAE) 7.235604217268416
# ----
# 2019-02-19 04:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 189
# * Prediction Accuracy (MAE) 6.747761474481559
# ----
# 2019-02-19 05:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 190
# * Prediction Accuracy (MAE) 6.333954553179272
# ----
# 2019-02-19 05:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 191
# * Prediction Accuracy (MAE) 6.7750549129423465
# ----
# 2019-02-19 06:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 192
# * Prediction Accuracy (MAE) 7.025593655444568
# ----
# 2019-02-19 06:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 193
# * Prediction Accuracy (MAE) 5.768671738912427
# ----
# 2019-02-19 07:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 194
# * Prediction Accuracy (MAE) 7.35454299239389
# ----
# 2019-02-19 07:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 195
# * Prediction Accuracy (MAE) 6.315445402167626
# ----
# 2019-02-19 08:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 196
# * Prediction Accuracy (MAE) 6.2018011952426155
# ----
# 2019-02-19 08:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 197
# * Prediction Accuracy (MAE) 6.754051155588412
# ----
# 2019-02-19 09:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 198
# * Prediction Accuracy (MAE) 5.948747058369516
# ----
# 2019-02-19 09:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 199
# * Prediction Accuracy (MAE) 6.0801227788412096
# ----
# 2019-02-19 10:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 200
# * Prediction Accuracy (MAE) 6.16098348180451
# ----
# 2019-02-19 10:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 201
# * Prediction Accuracy (MAE) 6.676521158925481
# ----
# 2019-02-19 11:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 202
# * Prediction Accuracy (MAE) 6.36039864257788
# ----
# 2019-02-19 11:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 203
# * Prediction Accuracy (MAE) 6.110046566539739
# ----
# 2019-02-19 12:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 204
# * Prediction Accuracy (MAE) 6.482559676864294
# ----
# 2019-02-19 12:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 205
# * Prediction Accuracy (MAE) 7.202578260011829
# ----
# 2019-02-19 13:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 206
# * Prediction Accuracy (MAE) 7.169463180860518
# ----
# 2019-02-19 13:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 207
# * Prediction Accuracy (MAE) 7.149011077243924
# ----
# 2019-02-19 14:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 208
# * Prediction Accuracy (MAE) 7.281610524438219
# ----
# 2019-02-19 14:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 209
# * Prediction Accuracy (MAE) 8.390744716218922
# ----
# 2019-02-19 15:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 210
# * Prediction Accuracy (MAE) 7.201690237135106
# ----
# 2019-02-19 15:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 211
# * Prediction Accuracy (MAE) 7.320253952695114
# ----
# 2019-02-19 16:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 212
# * Prediction Accuracy (MAE) 7.603325915341621
# ----
# 2019-02-19 16:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 213
# * Prediction Accuracy (MAE) 9.048241503959815
# ----
# 2019-02-19 17:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 214
# * Prediction Accuracy (MAE) 6.992092665628952
# ----
# 2019-02-19 17:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 215
# * Prediction Accuracy (MAE) 6.448314023449249
# ----
# 2019-02-19 18:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 216
# * Prediction Accuracy (MAE) 7.434022297642603
# ----
# 2019-02-19 18:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 217
# * Prediction Accuracy (MAE) 7.154786485680676
# ----
# 2019-02-19 19:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 218
# * Prediction Accuracy (MAE) 6.450755108962346
# ----
# 2019-02-19 19:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 219
# * Prediction Accuracy (MAE) 7.288624939526015
# ----
# 2019-02-19 20:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 220
# * Prediction Accuracy (MAE) 8.286089150136453
# ----
# 2019-02-19 20:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 221
# * Prediction Accuracy (MAE) 10.222051607823916
# ----
# 2019-02-19 21:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 222
# * Prediction Accuracy (MAE) 6.844888671415808
# ----
# 2019-02-19 21:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 223
# * Prediction Accuracy (MAE) 7.872281828157067
# ----
# 2019-02-19 22:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 224
# * Prediction Accuracy (MAE) 7.8304711673948475
# ----
# 2019-02-19 22:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 225
# * Prediction Accuracy (MAE) 7.404064934265819
# ----
# 2019-02-19 23:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 226
# * Prediction Accuracy (MAE) 7.599652185905801
# ----
# 2019-02-19 23:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 227
# * Prediction Accuracy (MAE) 7.4980474609041305
# ----
# 2019-02-20 00:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 228
# * Prediction Accuracy (MAE) 6.938983331435594
# ----
# 2019-02-20 00:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 229
# * Prediction Accuracy (MAE) 8.28488720307658
# ----
# 2019-02-20 01:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 230
# * Prediction Accuracy (MAE) 8.13316814573039
# ----
# 2019-02-20 01:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 231
# * Prediction Accuracy (MAE) 8.17501393400409
# ----
# 2019-02-20 02:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 232
# * Prediction Accuracy (MAE) 10.447914226542007
# ----
# 2019-02-20 02:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 233
# * Prediction Accuracy (MAE) 6.396310957770811
# ----
# 2019-02-20 03:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 234
# * Prediction Accuracy (MAE) 9.252853031256322
# ----
# 2019-02-20 03:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 235
# * Prediction Accuracy (MAE) 6.945601312365443
# ----
# 2019-02-20 04:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 236
# * Prediction Accuracy (MAE) 7.446580678148225
# ----
# 2019-02-20 04:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 237
# * Prediction Accuracy (MAE) 7.226528444298702
# ----
# 2019-02-20 05:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 238
# * Prediction Accuracy (MAE) 6.271108757540357
# ----
# 2019-02-20 05:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 239
# * Prediction Accuracy (MAE) 6.421794337160021
# ----
# 2019-02-20 06:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 240
# * Prediction Accuracy (MAE) 7.265316650517454
# ----
# 2019-02-20 06:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 241
# * Prediction Accuracy (MAE) 7.302837768899661
# ----
# 2019-02-20 07:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 242
# * Prediction Accuracy (MAE) 7.011192776876322
# ----
# 2019-02-20 07:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 243
# * Prediction Accuracy (MAE) 9.627355142636727
# ----
# 2019-02-20 08:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 244
# * Prediction Accuracy (MAE) 5.955075593221618
# ----
# 2019-02-20 08:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 245
# * Prediction Accuracy (MAE) 5.91699080991804
# ----
# 2019-02-20 09:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 246
# * Prediction Accuracy (MAE) 6.625282286595279
# ----
# 2019-02-20 09:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 247
# * Prediction Accuracy (MAE) 10.488916903266274
# ----
# 2019-02-20 10:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 248
# * Prediction Accuracy (MAE) 7.039104500392539
# ----
# 2019-02-20 10:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 249
# * Prediction Accuracy (MAE) 6.907688895875046
# ----
# 2019-02-20 11:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 250
# * Prediction Accuracy (MAE) 8.229331622218943
# ----
# 2019-02-20 11:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 251
# * Prediction Accuracy (MAE) 7.624451797669519
# ----
# 2019-02-20 12:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 252
# * Prediction Accuracy (MAE) 7.490709238347937
# ----
# 2019-02-20 12:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 253
# * Prediction Accuracy (MAE) 7.102187997932984
# ----
# 2019-02-20 13:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 254
# * Prediction Accuracy (MAE) 6.9067000086155375
# ----
# 2019-02-20 13:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 255
# * Prediction Accuracy (MAE) 8.070410579755046
# ----
# 2019-02-20 14:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 256
# * Prediction Accuracy (MAE) 7.668717500973302
# ----
# 2019-02-20 14:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 257
# * Prediction Accuracy (MAE) 8.0599348635616
# ----
# 2019-02-20 15:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 258
# * Prediction Accuracy (MAE) 7.9097919838940465
# ----
# 2019-02-20 15:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 259
# * Prediction Accuracy (MAE) 7.1910377186618755
# ----
# 2019-02-20 16:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 260
# * Prediction Accuracy (MAE) 8.820895662784539
# ----
# 2019-02-20 16:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 261
# * Prediction Accuracy (MAE) 10.586781779433744
# ----
# 2019-02-20 17:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 262
# * Prediction Accuracy (MAE) 7.363370255927266
# ----
# 2019-02-20 17:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 263
# * Prediction Accuracy (MAE) 7.020904794338783
# ----
# 2019-02-20 18:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 264
# * Prediction Accuracy (MAE) 8.786464682645708
# ----
# 2019-02-20 18:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 265
# * Prediction Accuracy (MAE) 6.967151086804847
# ----
# 2019-02-20 19:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 266
# * Prediction Accuracy (MAE) 7.3280794576992605
# ----
# 2019-02-20 19:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 267
# * Prediction Accuracy (MAE) 8.12002052312805
# ----
# 2019-02-20 20:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 268
# * Prediction Accuracy (MAE) 8.68752234823293
# ----
# 2019-02-20 20:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 269
# * Prediction Accuracy (MAE) 10.820003626175735
# ----
# 2019-02-20 21:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 270
# * Prediction Accuracy (MAE) 8.179299713634325
# ----
# 2019-02-20 21:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 271
# * Prediction Accuracy (MAE) 7.165458774373026
# ----
# 2019-02-20 22:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 272
# * Prediction Accuracy (MAE) 7.199505968541636
# ----
# 2019-02-20 22:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 273
# * Prediction Accuracy (MAE) 7.801888740012015
# ----
# 2019-02-20 23:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 274
# * Prediction Accuracy (MAE) 9.204604520932554
# ----
# 2019-02-20 23:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 275
# * Prediction Accuracy (MAE) 8.042332494426066
# ----
# 2019-02-21 00:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 276
# * Prediction Accuracy (MAE) 7.566058281256005
# ----
# 2019-02-21 00:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 277
# * Prediction Accuracy (MAE) 8.0361359603974
# ----
# 2019-02-21 01:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 278
# * Prediction Accuracy (MAE) 7.72611643576615
# ----
# 2019-02-21 01:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 279
# * Prediction Accuracy (MAE) 11.921367401453406
# ----
# 2019-02-21 02:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 280
# * Prediction Accuracy (MAE) 9.675105046528383
# ----
# 2019-02-21 02:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 281
# * Prediction Accuracy (MAE) 8.019875672407869
# ----
# 2019-02-21 03:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 282
# * Prediction Accuracy (MAE) 8.114316145594636
# ----
# 2019-02-21 03:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 283
# * Prediction Accuracy (MAE) 7.198401376834947
# ----
# 2019-02-21 04:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 284
# * Prediction Accuracy (MAE) 8.372229521512438
# ----
# 2019-02-21 04:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 285
# * Prediction Accuracy (MAE) 6.043323761637961
# ----
# 2019-02-21 05:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 286
# * Prediction Accuracy (MAE) 6.466096537224873
# ----
# 2019-02-21 05:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 287
# * Prediction Accuracy (MAE) 6.906691087074791
# ----
# 2019-02-21 06:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 288
# * Prediction Accuracy (MAE) 6.303304381214632
# ----
# 2019-02-21 06:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 289
# * Prediction Accuracy (MAE) 7.0065622534664085
# ----
# 2019-02-21 07:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 290
# * Prediction Accuracy (MAE) 7.197229061073499
# ----
# 2019-02-21 07:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 291
# * Prediction Accuracy (MAE) 7.675956011646805
# ----
# 2019-02-21 08:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 292
# * Prediction Accuracy (MAE) 5.998606841391605
# ----
# 2019-02-21 08:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 293
# * Prediction Accuracy (MAE) 7.094482173987441
# ----
# 2019-02-21 09:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 294
# * Prediction Accuracy (MAE) 8.099141471453105
# ----
# 2019-02-21 09:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 295
# * Prediction Accuracy (MAE) 7.22213257388436
# ----
# 2019-02-21 10:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 296
# * Prediction Accuracy (MAE) 9.66354973842583
# ----
# 2019-02-21 10:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 297
# * Prediction Accuracy (MAE) 7.03846431343665
# ----
# 2019-02-21 11:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 298
# * Prediction Accuracy (MAE) 8.037002676799036
# ----
# 2019-02-21 11:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 299
# * Prediction Accuracy (MAE) 6.819095046792332
# ----
# 2019-02-21 12:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 300
# * Prediction Accuracy (MAE) 8.542975163891395
# ----
# 2019-02-21 12:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 301
# * Prediction Accuracy (MAE) 7.5723672072771535
# ----
# 2019-02-21 13:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 302
# * Prediction Accuracy (MAE) 6.345696628543204
# ----
# 2019-02-21 13:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 303
# * Prediction Accuracy (MAE) 6.698669926247473
# ----
# 2019-02-21 14:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 304
# * Prediction Accuracy (MAE) 7.5225451050331325
# ----
# 2019-02-21 14:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 305
# * Prediction Accuracy (MAE) 7.060892150000061
# ----
# 2019-02-21 15:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 306
# * Prediction Accuracy (MAE) 9.003529301612334
# ----
# 2019-02-21 15:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 307
# * Prediction Accuracy (MAE) 7.382905446994255
# ----
# 2019-02-21 16:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 308
# * Prediction Accuracy (MAE) 7.610476392136338
# ----
# 2019-02-21 16:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 309
# * Prediction Accuracy (MAE) 7.268459523847962
# ----
# 2019-02-21 17:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 310
# * Prediction Accuracy (MAE) 6.502021712046912
# ----
# 2019-02-21 17:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 311
# * Prediction Accuracy (MAE) 7.098591500475661
# ----
# 2019-02-21 18:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 312
# * Prediction Accuracy (MAE) 6.5003540172664005
# ----
# 2019-02-21 18:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 313
# * Prediction Accuracy (MAE) 9.548763990515798
# ----
# 2019-02-21 19:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 314
# * Prediction Accuracy (MAE) 8.806422450649173
# ----
# 2019-02-21 19:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 315
# * Prediction Accuracy (MAE) 8.918856650616641
# ----
# 2019-02-21 20:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 316
# * Prediction Accuracy (MAE) 6.708080958113486
# ----
# 2019-02-21 20:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 317
# * Prediction Accuracy (MAE) 7.788298121371582
# ----
# 2019-02-21 21:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 318
# * Prediction Accuracy (MAE) 8.833361347490028
# ----
# 2019-02-21 21:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 319
# * Prediction Accuracy (MAE) 6.7536614455662995
# ----
# 2019-02-21 22:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 320
# * Prediction Accuracy (MAE) 7.48051304289941
# ----
# 2019-02-21 22:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 321
# * Prediction Accuracy (MAE) 6.838292982535221
# ----
# 2019-02-21 23:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 322
# * Prediction Accuracy (MAE) 7.685246160205896
# ----
# 2019-02-21 23:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 323
# * Prediction Accuracy (MAE) 8.16213147143608
# ----
# 2019-02-22 00:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 324
# * Prediction Accuracy (MAE) 8.651178422696523
# ----
# 2019-02-22 00:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 325
# * Prediction Accuracy (MAE) 9.085531308758577
# ----
# 2019-02-22 01:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 326
# * Prediction Accuracy (MAE) 7.764675766239967
# ----
# 2019-02-22 01:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 327
# * Prediction Accuracy (MAE) 8.252568352392359
# ----
# 2019-02-22 02:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 328
# * Prediction Accuracy (MAE) 6.984091022683391
# ----
# 2019-02-22 02:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 329
# * Prediction Accuracy (MAE) 8.217816561655551
# ----
# 2019-02-22 03:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 330
# * Prediction Accuracy (MAE) 7.682109574763501
# ----
# 2019-02-22 03:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 331
# * Prediction Accuracy (MAE) 7.62777782188928
# ----
# 2019-02-22 04:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 332
# * Prediction Accuracy (MAE) 7.720681042887393
# ----
# 2019-02-22 04:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 333
# * Prediction Accuracy (MAE) 6.552949832192598
# ----
# 2019-02-22 05:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 334
# * Prediction Accuracy (MAE) 6.528181429181454
# ----
# 2019-02-22 05:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 335
# * Prediction Accuracy (MAE) 6.537627989193181
# ----
# 2019-02-22 06:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 336
# * Prediction Accuracy (MAE) 5.744928550450976
# ----
#
# * Time to UPDATE the Model after 336 steps
#
# 2019-02-22 06:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 337
# * Prediction Accuracy (MAE) 6.752153156423742
# ----
# 2019-02-22 07:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 338
# * Prediction Accuracy (MAE) 6.112744271635084
# ----
# 2019-02-22 07:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 339
# * Prediction Accuracy (MAE) 6.798869846291583
# ----
# 2019-02-22 08:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 340
# * Prediction Accuracy (MAE) 6.832686248452563
# ----
# 2019-02-22 08:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 341
# * Prediction Accuracy (MAE) 8.533240711066592
# ----
# 2019-02-22 09:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 342
# * Prediction Accuracy (MAE) 5.857186737931172
# ----
# 2019-02-22 09:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 343
# * Prediction Accuracy (MAE) 5.592524751686014
# ----
# 2019-02-22 10:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 344
# * Prediction Accuracy (MAE) 6.780653832616484
# ----
# 2019-02-22 10:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 345
# * Prediction Accuracy (MAE) 7.141855044257185
# ----
# 2019-02-22 11:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 346
# * Prediction Accuracy (MAE) 6.671470105832782
# ----
# 2019-02-22 11:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 347
# * Prediction Accuracy (MAE) 6.411764662286408
# ----
# 2019-02-22 12:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 348
# * Prediction Accuracy (MAE) 6.232507128847225
# ----
# 2019-02-22 12:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 349
# * Prediction Accuracy (MAE) 6.290022101592707
# ----
# 2019-02-22 13:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 350
# * Prediction Accuracy (MAE) 7.8304828610019666
# ----
# 2019-02-22 13:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 351
# * Prediction Accuracy (MAE) 7.446692938800105
# ----
# 2019-02-22 14:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 352
# * Prediction Accuracy (MAE) 7.189095203609336
# ----
# 2019-02-22 14:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 353
# * Prediction Accuracy (MAE) 6.719447296151615
# ----
# 2019-02-22 15:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 354
# * Prediction Accuracy (MAE) 6.8296271691558985
# ----
# 2019-02-22 15:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 355
# * Prediction Accuracy (MAE) 7.154914768516344
# ----
# 2019-02-22 16:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 356
# * Prediction Accuracy (MAE) 7.173841633537361
# ----
# 2019-02-22 16:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 357
# * Prediction Accuracy (MAE) 9.052825506628182
# ----
# 2019-02-22 17:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 358
# * Prediction Accuracy (MAE) 7.217485152872604
# ----
# 2019-02-22 17:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 359
# * Prediction Accuracy (MAE) 9.340773659731827
# ----
# 2019-02-22 18:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 360
# * Prediction Accuracy (MAE) 7.627421885868728
# ----
# 2019-02-22 18:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 361
# * Prediction Accuracy (MAE) 8.10592649118191
# ----
# 2019-02-22 19:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 362
# * Prediction Accuracy (MAE) 9.516028673470093
# ----
# 2019-02-22 19:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 363
# * Prediction Accuracy (MAE) 8.437887562224926
# ----
# 2019-02-22 20:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 364
# * Prediction Accuracy (MAE) 7.73978195725633
# ----
# 2019-02-22 20:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 365
# * Prediction Accuracy (MAE) 7.219160402279598
# ----
# 2019-02-22 21:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 366
# * Prediction Accuracy (MAE) 7.455708630429858
# ----
# 2019-02-22 21:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 367
# * Prediction Accuracy (MAE) 7.193088804403542
# ----
# 2019-02-22 22:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 368
# * Prediction Accuracy (MAE) 8.107306449479626
# ----
# 2019-02-22 22:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 369
# * Prediction Accuracy (MAE) 8.082035711636733
# ----
# 2019-02-22 23:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 370
# * Prediction Accuracy (MAE) 6.817987170512933
# ----
# 2019-02-22 23:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 371
# * Prediction Accuracy (MAE) 7.4542333554470295
# ----
# 2019-02-23 00:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 372
# * Prediction Accuracy (MAE) 7.907643154067511
# ----
# 2019-02-23 00:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 373
# * Prediction Accuracy (MAE) 7.889116129064962
# ----
# 2019-02-23 01:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 374
# * Prediction Accuracy (MAE) 8.124355141811126
# ----
# 2019-02-23 01:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 375
# * Prediction Accuracy (MAE) 8.770234974637999
# ----
# 2019-02-23 02:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 376
# * Prediction Accuracy (MAE) 8.611998802528793
# ----
# 2019-02-23 02:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 377
# * Prediction Accuracy (MAE) 7.144013596332132
# ----
# 2019-02-23 03:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 378
# * Prediction Accuracy (MAE) 8.168425440707995
# ----
# 2019-02-23 03:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 379
# * Prediction Accuracy (MAE) 7.236491052296469
# ----
# 2019-02-23 04:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 380
# * Prediction Accuracy (MAE) 8.374022922663556
# ----
# 2019-02-23 04:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 381
# * Prediction Accuracy (MAE) 6.825370621706155
# ----
# 2019-02-23 05:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 382
# * Prediction Accuracy (MAE) 8.12870826340082
# ----
# 2019-02-23 05:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 383
# * Prediction Accuracy (MAE) 8.908261127458449
# ----
# 2019-02-23 06:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 384
# * Prediction Accuracy (MAE) 6.5986791211885665
# ----
# 2019-02-23 06:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 385
# * Prediction Accuracy (MAE) 6.517852741252096
# ----
# 2019-02-23 07:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 386
# * Prediction Accuracy (MAE) 6.920503946790906
# ----
# 2019-02-23 07:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 387
# * Prediction Accuracy (MAE) 7.283751081420391
# ----
# 2019-02-23 08:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 388
# * Prediction Accuracy (MAE) 6.984132056050978
# ----
# 2019-02-23 08:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 389
# * Prediction Accuracy (MAE) 8.196198324690005
# ----
# 2019-02-23 09:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 390
# * Prediction Accuracy (MAE) 9.086306669128263
# ----
# 2019-02-23 09:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 391
# * Prediction Accuracy (MAE) 6.823103758314635
# ----
# 2019-02-23 10:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 392
# * Prediction Accuracy (MAE) 7.127796472037233
# ----
# 2019-02-23 10:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 393
# * Prediction Accuracy (MAE) 6.983923407086189
# ----
# 2019-02-23 11:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 394
# * Prediction Accuracy (MAE) 8.038337189511564
# ----
# 2019-02-23 11:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 395
# * Prediction Accuracy (MAE) 8.145005011679052
# ----
# 2019-02-23 12:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 396
# * Prediction Accuracy (MAE) 9.417430460251579
# ----
# 2019-02-23 12:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 397
# * Prediction Accuracy (MAE) 8.041501498116094
# ----
# 2019-02-23 13:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 398
# * Prediction Accuracy (MAE) 7.638859407320027
# ----
# 2019-02-23 13:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 399
# * Prediction Accuracy (MAE) 9.712600934117074
# ----
# 2019-02-23 14:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 400
# * Prediction Accuracy (MAE) 8.588231515465134
# ----
# 2019-02-23 14:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 401
# * Prediction Accuracy (MAE) 8.288781408897835
# ----
# 2019-02-23 15:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 402
# * Prediction Accuracy (MAE) 8.996695131488995
# ----
# 2019-02-23 15:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 403
# * Prediction Accuracy (MAE) 9.832830898217546
# ----
# 2019-02-23 16:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 404
# * Prediction Accuracy (MAE) 9.333579292877435
# ----
# 2019-02-23 16:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 405
# * Prediction Accuracy (MAE) 10.825221534565628
# ----
# 2019-02-23 17:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 406
# * Prediction Accuracy (MAE) 8.813359346787948
# ----
# 2019-02-23 17:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 407
# * Prediction Accuracy (MAE) 7.79695649062824
# ----
# 2019-02-23 18:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 408
# * Prediction Accuracy (MAE) 9.78948399200679
# ----
# 2019-02-23 18:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 409
# * Prediction Accuracy (MAE) 10.728877459375264
# ----
# 2019-02-23 19:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 410
# * Prediction Accuracy (MAE) 8.444075663651754
# ----
# 2019-02-23 19:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 411
# * Prediction Accuracy (MAE) 8.050521195518819
# ----
# 2019-02-23 20:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 412
# * Prediction Accuracy (MAE) 7.875624036947329
# ----
# 2019-02-23 20:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 413
# * Prediction Accuracy (MAE) 8.46962375450865
# ----
# 2019-02-23 21:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 414
# * Prediction Accuracy (MAE) 7.971696070932895
# ----
# 2019-02-23 21:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 415
# * Prediction Accuracy (MAE) 8.48288373796625
# ----
# 2019-02-23 22:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 416
# * Prediction Accuracy (MAE) 8.83006905934863
# ----
# 2019-02-23 22:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 417
# * Prediction Accuracy (MAE) 8.50893598589507
# ----
# 2019-02-23 23:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 418
# * Prediction Accuracy (MAE) 9.414849984391656
# ----
# 2019-02-23 23:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 419
# * Prediction Accuracy (MAE) 8.470997490958242
# ----
# 2019-02-24 00:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 420
# * Prediction Accuracy (MAE) 8.160770907778932
# ----
# 2019-02-24 00:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 421
# * Prediction Accuracy (MAE) 8.170279664678713
# ----
# 2019-02-24 01:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 422
# * Prediction Accuracy (MAE) 7.192974816025881
# ----
# 2019-02-24 01:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 423
# * Prediction Accuracy (MAE) 8.1763958357078
# ----
# 2019-02-24 02:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 424
# * Prediction Accuracy (MAE) 8.16433378028974
# ----
# 2019-02-24 02:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 425
# * Prediction Accuracy (MAE) 7.175336274256832
# ----
# 2019-02-24 03:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 426
# * Prediction Accuracy (MAE) 8.958424646132675
# ----
# 2019-02-24 03:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 427
# * Prediction Accuracy (MAE) 8.97352139508686
# ----
# 2019-02-24 04:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 428
# ...
# (1, 5975)
# (1, 12, 11950)
# * Time step 506
# * Prediction Accuracy (MAE) 6.989148207882938
# ----
# 2019-02-25 19:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 507
# * Prediction Accuracy (MAE) 8.400333162578189
# ----
# 2019-02-25 20:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 508
# * Prediction Accuracy (MAE) 7.5686627323557545
# ----
# 2019-02-25 20:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 509
# * Prediction Accuracy (MAE) 9.316224874833246
# ----
# 2019-02-25 21:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 510
# * Prediction Accuracy (MAE) 8.890322319894452
# ----
# 2019-02-25 21:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 511
# * Prediction Accuracy (MAE) 7.117161777367235
# ----
# 2019-02-25 22:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 512
# * Prediction Accuracy (MAE) 8.29396497227143
# ----
# 2019-02-25 22:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 513
# * Prediction Accuracy (MAE) 7.134184077255292
# ----
# 2019-02-25 23:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 514
# * Prediction Accuracy (MAE) 7.50251986769717
# ----
# 2019-02-25 23:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 515
# * Prediction Accuracy (MAE) 7.566437899726651
# ----
# 2019-02-26 00:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 516
# * Prediction Accuracy (MAE) 7.413992099939833
# ----
# 2019-02-26 00:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 517
# * Prediction Accuracy (MAE) 7.2865427684642645
# ----
# 2019-02-26 01:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 518
# * Prediction Accuracy (MAE) 9.016740481922774
# ----
# 2019-02-26 01:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 519
# * Prediction Accuracy (MAE) 9.947735024737957
# ----
# 2019-02-26 02:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 520
# * Prediction Accuracy (MAE) 8.796081610841435
# ----
# 2019-02-26 02:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 521
# * Prediction Accuracy (MAE) 8.279198638821878
# ----
# 2019-02-26 03:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 522
# * Prediction Accuracy (MAE) 7.47707472717731
# ----
# 2019-02-26 03:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 523
# * Prediction Accuracy (MAE) 6.62513034303801
# ----
# 2019-02-26 04:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 524
# * Prediction Accuracy (MAE) 8.082300520939754
# ----
# 2019-02-26 04:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 525
# * Prediction Accuracy (MAE) 5.759714446933932
# ----
# 2019-02-26 05:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 526
# * Prediction Accuracy (MAE) 8.802424505722284
# ----
# 2019-02-26 05:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 527
# * Prediction Accuracy (MAE) 5.739602833199991
# ----
# 2019-02-26 06:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 528
# * Prediction Accuracy (MAE) 6.2253500440358405
# ----
# 2019-02-26 06:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 529
# * Prediction Accuracy (MAE) 6.077601351629734
# ----
# 2019-02-26 07:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 530
# * Prediction Accuracy (MAE) 10.804139229526664
# ----
# 2019-02-26 07:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 531
# * Prediction Accuracy (MAE) 12.31715220812079
# ----
# 2019-02-26 08:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 532
# * Prediction Accuracy (MAE) 7.046512997583561
# ----
# 2019-02-26 08:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 533
# * Prediction Accuracy (MAE) 5.43542703841293
# ----
# 2019-02-26 09:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 534
# * Prediction Accuracy (MAE) 5.815118144463347
# ----
# 2019-02-26 09:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 535
# * Prediction Accuracy (MAE) 6.327028492027439
# ----
# 2019-02-26 10:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 536
# * Prediction Accuracy (MAE) 10.331477018931448
# ----
# 2019-02-26 10:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 537
# * Prediction Accuracy (MAE) 6.470958212841917
# ----
# 2019-02-26 11:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 538
# * Prediction Accuracy (MAE) 6.315394866927226
# ----
# 2019-02-26 11:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 539
# * Prediction Accuracy (MAE) 6.694377327260823
# ----
# 2019-02-26 12:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 540
# * Prediction Accuracy (MAE) 6.947184128472036
# ----
# 2019-02-26 12:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 541
# * Prediction Accuracy (MAE) 7.375252189455285
# ----
# 2019-02-26 13:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 542
# * Prediction Accuracy (MAE) 6.886221620773261
# ----
# 2019-02-26 13:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 543
# * Prediction Accuracy (MAE) 6.809598253209729
# ----
# 2019-02-26 14:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 544
# * Prediction Accuracy (MAE) 7.903174785050178
# ----
# 2019-02-26 14:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 545
# * Prediction Accuracy (MAE) 7.259793749831474
# ----
# 2019-02-26 15:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 546
# * Prediction Accuracy (MAE) 8.905816147625572
# ----
# 2019-02-26 15:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 547
# * Prediction Accuracy (MAE) 6.905942659609488
# ----
# 2019-02-26 16:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 548
# * Prediction Accuracy (MAE) 7.265591484957744
# ----
# 2019-02-26 16:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 549
# * Prediction Accuracy (MAE) 7.1642802457147905
# ----
# 2019-02-26 17:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 550
# * Prediction Accuracy (MAE) 7.54009575068706
# ----
# 2019-02-26 17:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 551
# * Prediction Accuracy (MAE) 7.765452401979295
# ----
# 2019-02-26 18:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 552
# * Prediction Accuracy (MAE) 8.580785721382627
# ----
# 2019-02-26 18:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 553
# * Prediction Accuracy (MAE) 9.837435422360622
# ----
# 2019-02-26 19:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 554
# * Prediction Accuracy (MAE) 7.285625374219681
# ----
# 2019-02-26 19:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 555
# * Prediction Accuracy (MAE) 6.656628410523596
# ----
# 2019-02-26 20:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 556
# * Prediction Accuracy (MAE) 8.230938508643028
# ----
# 2019-02-26 20:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 557
# * Prediction Accuracy (MAE) 8.570404693273627
# ----
# 2019-02-26 21:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 558
# * Prediction Accuracy (MAE) 8.607184942237568
# ----
# 2019-02-26 21:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 559
# * Prediction Accuracy (MAE) 7.236045191297202
# ----
# 2019-02-26 22:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 560
# * Prediction Accuracy (MAE) 7.7996789069095795
# ----
# 2019-02-26 22:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 561
# * Prediction Accuracy (MAE) 7.237773035737434
# ----
# 2019-02-26 23:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 562
# * Prediction Accuracy (MAE) 8.105233622373403
# ----
# 2019-02-26 23:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 563
# * Prediction Accuracy (MAE) 7.824075570048009
# ----
# 2019-02-27 00:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 564
# * Prediction Accuracy (MAE) 6.8627762316842285
# ----
# 2019-02-27 00:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 565
# * Prediction Accuracy (MAE) 7.650223445218417
# ----
# 2019-02-27 01:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 566
# * Prediction Accuracy (MAE) 8.324802870823678
# ----
# 2019-02-27 01:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 567
# * Prediction Accuracy (MAE) 7.712498050767862
# ----
# 2019-02-27 02:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 568
# * Prediction Accuracy (MAE) 9.17980119892079
# ----
# 2019-02-27 02:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 569
# * Prediction Accuracy (MAE) 8.281107800571888
# ----
# 2019-02-27 03:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 570
# * Prediction Accuracy (MAE) 7.679085408432773
# ----
# 2019-02-27 03:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 571
# * Prediction Accuracy (MAE) 7.1906655102027175
# ----
# 2019-02-27 04:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 572
# * Prediction Accuracy (MAE) 7.742567241614747
# ----
# 2019-02-27 04:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 573
# * Prediction Accuracy (MAE) 8.790266919660212
# ----
# 2019-02-27 05:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 574
# * Prediction Accuracy (MAE) 6.852091089534745
# ----
# 2019-02-27 05:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 575
# * Prediction Accuracy (MAE) 6.137588918666773
# ----
# 2019-02-27 06:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 576
# * Prediction Accuracy (MAE) 7.8983833053411825
# ----
# 2019-02-27 06:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 577
# * Prediction Accuracy (MAE) 7.575206277985244
# ----
# 2019-02-27 07:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 578
# * Prediction Accuracy (MAE) 7.487708159177994
# ----
# 2019-02-27 07:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 579
# * Prediction Accuracy (MAE) 6.779311008317963
# ----
# 2019-02-27 08:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 580
# * Prediction Accuracy (MAE) 7.1929286701571735
# ----
# 2019-02-27 08:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 581
# * Prediction Accuracy (MAE) 6.159616083884023
# ----
# 2019-02-27 09:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 582
# * Prediction Accuracy (MAE) 6.268807445802501
# ----
# 2019-02-27 09:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 583
# * Prediction Accuracy (MAE) 6.603287198182293
# ----
# 2019-02-27 10:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 584
# * Prediction Accuracy (MAE) 7.802946415619778
# ----
# 2019-02-27 10:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 585
# * Prediction Accuracy (MAE) 7.64314760329133
# ----
# 2019-02-27 11:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 586
# * Prediction Accuracy (MAE) 6.197582678003874
# ----
# 2019-02-27 11:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 587
# * Prediction Accuracy (MAE) 6.878067411836772
# ----
# 2019-02-27 12:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 588
# * Prediction Accuracy (MAE) 6.7198780990246245
# ----
# 2019-02-27 12:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 589
# * Prediction Accuracy (MAE) 6.345806773511395
# ----
# 2019-02-27 13:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 590
# * Prediction Accuracy (MAE) 7.216849114520108
# ----
# 2019-02-27 13:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 591
# * Prediction Accuracy (MAE) 6.789905168887805
# ----
# 2019-02-27 14:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 592
# * Prediction Accuracy (MAE) 8.069749203412426
# ----
# 2019-02-27 14:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 593
# * Prediction Accuracy (MAE) 7.1519380411571705
# ----
# 2019-02-27 15:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 594
# * Prediction Accuracy (MAE) 8.09634227260702
# ----
# 2019-02-27 15:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 595
# * Prediction Accuracy (MAE) 8.333793826265966
# ----
# 2019-02-27 16:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 596
# * Prediction Accuracy (MAE) 7.323803584996409
# ----
# 2019-02-27 16:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 597
# * Prediction Accuracy (MAE) 6.862066186340042
# ----
# 2019-02-27 17:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 598
# * Prediction Accuracy (MAE) 6.830804639946249
# ----
# 2019-02-27 17:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 599
# * Prediction Accuracy (MAE) 7.273825430204486
# ----
# 2019-02-27 18:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 600
# * Prediction Accuracy (MAE) 9.129434361581456
# ----
# 2019-02-27 18:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 601
# * Prediction Accuracy (MAE) 7.833013133718687
# ----
# 2019-02-27 19:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 602
# * Prediction Accuracy (MAE) 7.185134615045248
# ----
# 2019-02-27 19:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 603
# * Prediction Accuracy (MAE) 8.878304446823096
# ----
# 2019-02-27 20:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 604
# * Prediction Accuracy (MAE) 8.07960614949954
# ----
# 2019-02-27 20:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 605
# * Prediction Accuracy (MAE) 7.318604696541325
# ----
# 2019-02-27 21:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 606
# * Prediction Accuracy (MAE) 6.821817903790008
# ----
# 2019-02-27 21:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 607
# * Prediction Accuracy (MAE) 7.449112868144044
# ----
# 2019-02-27 22:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 608
# * Prediction Accuracy (MAE) 6.868033202907826
# ----
# 2019-02-27 22:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 609
# * Prediction Accuracy (MAE) 7.091971343298139
# ----
# 2019-02-27 23:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 610
# * Prediction Accuracy (MAE) 7.715093567448599
# ----
# 2019-02-27 23:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 611
# * Prediction Accuracy (MAE) 7.432955969527326
# ----
# 2019-02-28 00:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 612
# * Prediction Accuracy (MAE) 8.988853800419143
# ----
# 2019-02-28 00:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 613
# * Prediction Accuracy (MAE) 9.90636997581621
# ----
# 2019-02-28 01:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 614
# * Prediction Accuracy (MAE) 8.821303747125146
# ----
# 2019-02-28 01:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 615
# * Prediction Accuracy (MAE) 9.154074151930688
# ----
# 2019-02-28 02:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 616
# * Prediction Accuracy (MAE) 8.903420165870717
# ----
# 2019-02-28 02:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 617
# * Prediction Accuracy (MAE) 6.862394637629203
# ----
# 2019-02-28 03:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 618
# * Prediction Accuracy (MAE) 7.549909473065605
# ----
# 2019-02-28 03:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 619
# * Prediction Accuracy (MAE) 8.72451804280676
# ----
# 2019-02-28 04:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 620
# * Prediction Accuracy (MAE) 9.517725895421876
# ----
# 2019-02-28 04:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 621
# * Prediction Accuracy (MAE) 5.718886463204629
# ----
# 2019-02-28 05:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 622
# * Prediction Accuracy (MAE) 8.379898766038597
# ----
# 2019-02-28 05:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 623
# * Prediction Accuracy (MAE) 6.7403068679353115
# ----
# 2019-02-28 06:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 624
# * Prediction Accuracy (MAE) 6.554821313679796
# ----
# 2019-02-28 06:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 625
# * Prediction Accuracy (MAE) 6.640623743699719
# ----
# 2019-02-28 07:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 626
# * Prediction Accuracy (MAE) 6.677796167163142
# ----
# 2019-02-28 07:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 627
# * Prediction Accuracy (MAE) 5.977915068703697
# ----
# 2019-02-28 08:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 628
# * Prediction Accuracy (MAE) 6.049637345383974
# ----
# 2019-02-28 08:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 629
# * Prediction Accuracy (MAE) 6.125886153281961
# ----
# 2019-02-28 09:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 630
# * Prediction Accuracy (MAE) 6.310137153053442
# ----
# 2019-02-28 09:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 631
# * Prediction Accuracy (MAE) 5.781217612211328
# ----
# 2019-02-28 10:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 632
# * Prediction Accuracy (MAE) 6.3023697521108755
# ----
# 2019-02-28 10:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 633
# * Prediction Accuracy (MAE) 6.605253220044228
# ----
# 2019-02-28 11:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 634
# * Prediction Accuracy (MAE) 6.12778426986154
# ----
# 2019-02-28 11:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 635
# * Prediction Accuracy (MAE) 6.645976827919821
# ----
# 2019-02-28 12:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 636
# * Prediction Accuracy (MAE) 7.2294038065727255
# ----
# 2019-02-28 12:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 637
# * Prediction Accuracy (MAE) 7.728829830252574
# ----
# 2019-02-28 13:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 638
# * Prediction Accuracy (MAE) 6.561349625737575
# ----
# 2019-02-28 13:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 639
# * Prediction Accuracy (MAE) 7.444070666008803
# ----
# 2019-02-28 14:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 640
# * Prediction Accuracy (MAE) 7.440560807811257
# ----
# 2019-02-28 14:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 641
# * Prediction Accuracy (MAE) 6.992108847414089
# ----
# 2019-02-28 15:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 642
# * Prediction Accuracy (MAE) 8.045752172729975
# ----
# 2019-02-28 15:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 643
# * Prediction Accuracy (MAE) 7.139641376919992
# ----
# 2019-02-28 16:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 644
# * Prediction Accuracy (MAE) 7.452321894261681
# ----
# 2019-02-28 16:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 645
# * Prediction Accuracy (MAE) 6.808184179461903
# ----
# 2019-02-28 17:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 646
# * Prediction Accuracy (MAE) 8.411272318925507
# ----
# 2019-02-28 17:30:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 647
# * Prediction Accuracy (MAE) 9.45706970546557
# ----
# 2019-02-28 18:00:00
# (1, 5975)
# (1, 12, 11950)
# * Time step 648
# * Prediction Accuracy (MAE) 6.2765276229916775
# ----

# %%
np.mean(rmse_list)
# Out:
# 12.675098579659378

# %%
np.mean(mae_list)
# Out:
# 8.114804389177738

# %%
RMSE_MEAN = np.mean(rmse_list,axis=0).mean(axis=1)
RMSE_STD =  np.std(rmse_list,axis=0).std(axis=1)

for i in range(len(RMSE_MEAN)):
    print('t+'+str(i+1)+' RMSE MEAN ' +str(np.round(RMSE_MEAN[i],3))+' +- '+str(np.round(RMSE_STD[i],3)))
    print('')
# Out:
# t+1 RMSE MEAN 11.427 +- 2.247
#
# t+2 RMSE MEAN 11.796 +- 2.525
#
# t+3 RMSE MEAN 12.035 +- 2.636
#
# t+4 RMSE MEAN 12.093 +- 2.335
#
# t+5 RMSE MEAN 12.381 +- 2.374
#
# t+6 RMSE MEAN 12.744 +- 2.545
#
# t+7 RMSE MEAN 13.144 +- 3.128
#
# t+8 RMSE MEAN 13.119 +- 2.418
#
# t+9 RMSE MEAN 13.193 +- 2.113
#
# t+10 RMSE MEAN 13.314 +- 2.083
#
# t+11 RMSE MEAN 13.391 +- 2.032
#
# t+12 RMSE MEAN 13.464 +- 1.996

# %%
MAE_MEAN = np.mean(mae_list,axis=0).mean(axis=1)
MAE_STD =  np.std(mae_list,axis=0).std(axis=1)

for i in range(len(MAE_MEAN)):
    print('t+'+str(i+1)+' MAE MEAN ' +str(np.round(MAE_MEAN[i],3))+' +- '+str(np.round(MAE_STD[i],3)))
    print('')
# Out:
# t+1 MAE MEAN 6.886 +- 1.376
#
# t+2 MAE MEAN 7.154 +- 1.723
#
# t+3 MAE MEAN 7.374 +- 1.819
#
# t+4 MAE MEAN 7.562 +- 1.65
#
# t+5 MAE MEAN 7.827 +- 1.621
#
# t+6 MAE MEAN 8.165 +- 1.846
#
# t+7 MAE MEAN 8.506 +- 2.682
#
# t+8 MAE MEAN 8.59 +- 1.905
#
# t+9 MAE MEAN 8.685 +- 1.519
#
# t+10 MAE MEAN 8.791 +- 1.47
#
# t+11 MAE MEAN 8.876 +- 1.404
#
# t+12 MAE MEAN 8.963 +- 1.357

# %%
with open('STL_GCN_RMSE.pkl', 'wb') as f:  
    pickle.dump(rmse_list, f)

# !cp STL_GCN_RMSE.pkl "drive/MyDrive/Colab Notebooks/MTL traffic forecasting/Results/"
print('RMSE')


with open('STL_GCN_MAE.pkl', 'wb') as f:  
    pickle.dump(mae_list, f)

# !cp STL_GCN_MAE.pkl "drive/MyDrive/Colab Notebooks/MTL traffic forecasting/Results/"
print('MAE')
# Out:
# RMSE
# MAE

# %%
while True:pass
